# %%
import torch
import matplotlib.pyplot as plt

# %%
curves = torch.load("mol_gin_end_to_end_three_layers_curves")
plt.plot(curves['Val'], label="Val")
plt.plot(curves['Test'], label="Test")
plt.plot(curves['Train'], label="Train")
plt.legend()
plt.show()
